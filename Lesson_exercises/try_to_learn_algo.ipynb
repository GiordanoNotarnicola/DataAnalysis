# %% [markdown]
# Algo to find maximun value in a list

# %%
a=[1, 3, 4, 3, 6, 7, 9, 12, 6]
def f_max(values:list)->int:
    maxi=values[0]
    for i in values:
        if maxi<i:
            maxi=i
    return maxi

f_max(a)
# Out:
# 12

# %% [markdown]
# Algo to find a specific number in a list

# %%
a=[1, 3, 4, 3, 6, 7, 8, 9, 12, 6]
def seq_search(lista:list, n:int)->str:
    passi=0
    for i, val in enumerate(lista):
        passi+=1
        if val==n:
            return f"{n} è presente in posizione {i}, numero passi {passi}"
    return f"{n} non è presente in lista"
seq_search(a, 9)
# Out:
# '9 è presente in posizione 7'

# %% [markdown]
# Binary research algo

# %%
a=[1, 3, 4, 3, 6, 7, 8, 9, 12, 6]
a=a.sort()
def bin_res(lista:list, n:int)->int:
    low=0
    high=len(lista)-1
    passi=0
    while low<=high:
        passi+=1
        mid=(low+high)//2
        if n==mid:
            print()
